# %% [markdown]
# <a href="https://colab.research.google.com/github/Pietervo16/ML_combined/blob/Google-colab/Combined_scripts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q --upgrade git+https://github.com/jveenland/tm10007_ml.git
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for ktml (setup.py) ... done

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from worclipo.load_data import load_data
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import preprocessing
from sklearn import decomposition
from sklearn import discriminant_analysis
from sklearn import metrics
from sklearn import model_selection
from sklearn.metrics import RocCurveDisplay, accuracy_score
from scipy import stats
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.kernel_approximation import RBFSampler
from sklearn.metrics.pairwise import rbf_kernel, sigmoid_kernel
from scipy.stats import ttest_ind
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.feature_selection import RFECV
from sklearn.model_selection import LearningCurveDisplay, learning_curve

data = load_data()
data.dropna(how='all')

print(f'The number of samples: {len(data.index)}')
print(f'The number of columns: {len(data.columns)}')

# Take the labels of the data
label = data.pop('label')
data = data.to_numpy()
label = label.to_numpy()

sss = model_selection.StratifiedKFold(n_splits=5)
mean_fpr = np.linspace(0, 1, 100)  # we maken een vector aan waarop we gaan interpoleren
tprs = []
auc = []
specificities = []
sensitivities = []

for train_index, test_index in sss.split(data, label):
    X_train = data[train_index]
    y_train = label[train_index]
    X_test = data[test_index]
    y_test = label[test_index]

    p_values_shapiro = []
    significant_p_values = []
    for column in range(X_train.shape[1]):
        _, p_value_shapiro = stats.shapiro(X_train[:,column])
        p_values_shapiro.append(p_value_shapiro)
    significant_p_values = sum(p < 0.05 for p in p_values_shapiro)
    print(f"Number of features that are not normally distributed {significant_p_values}")

    # Voer de t-test uit voor elke feature
    p_values = []

    label1_indices = [index for index, label in enumerate(y_train) if label == 'lipoma']
    label2_indices = [index for index, label in enumerate(y_train) if label == 'liposarcoma']

    for feature in range(X_train.shape[1]):  # num_features is het aantal features in je dataset
        group1 = X_train[label1_indices, feature]
        group2 = X_train[label2_indices, feature]
        _, p_value = ttest_ind(group1, group2)
        p_values.append(p_value)

    # Selecteer features met een p-waarde lager dan de drempel (bijv. 0.05)
    selected_features = [i for i, p_value in enumerate(p_values) if p_value < 0.02]

    # Drop de niet-significante features
    data_selected = X_train[:, selected_features]
    test_selected = X_test[:, selected_features]

    # Maak een DataFrame met de geselecteerde features
    selected_data = pd.DataFrame(data_selected)

    # Voeg de kolomnamen toe aan de DataFrame
    selected_data.columns = [f"feature_{i+1}" for i in selected_features]

    # Definieer de pipeline met schaling, LDA en SVM-classifier
    pipeline = Pipeline([
        ('scaler', preprocessing.StandardScaler()),
        ('feature_selection', RFECV(estimator=SVC(kernel='linear'), scoring='accuracy')),
        ('lda', LinearDiscriminantAnalysis())
    ])

    # Definieer het parametergrid om te doorzoeken
    param_grid = {
        'scaler': [preprocessing.StandardScaler(), MinMaxScaler(), RobustScaler()],
        'feature_selection__step': [1, 5, 10],
        'lda__n_components': [None],
        'lda__solver': ['lsqr', 'eigen', 'svd'],  # De solver voor LDA
        'lda__shrinkage': ['auto'],  # L1 en L2 regularisatie (penalty)
    }

    # Initialiseer de grid search
    grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy')

    # Voer de grid search uit op de data
    grid_search.fit(selected_data.values, y_train)

    # Bekijk de beste parameters en score
    print("Best parameters:", grid_search.best_params_)
    print("Validation accuracy:", grid_search.best_score_)

    # Voorspel op de testset met het beste model
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(test_selected)
    y_proba = best_model.predict_proba(test_selected)[:, 1]

    #labels 0 of 1 maken
    label_encoder = preprocessing.LabelEncoder()
    y_test = label_encoder.fit_transform(y_test)
    y_pred = label_encoder.fit_transform(y_pred)

    # Evalueren van het beste model op de testset
    accuracy = accuracy_score(y_test, y_pred)
    print("Test set accuracy:", accuracy)

    train_size, train_score, test_score = learning_curve(best_model, selected_data, y_train)
    display = LearningCurveDisplay(train_sizes=train_size, train_scores=train_score, test_scores=test_score, score_name="Accuracy")
    display.plot()
    plt.show()


    confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
    sensitivity = confusion_matrix[1, 1] / (confusion_matrix[1, 1] + confusion_matrix[1, 0])
    specificity = confusion_matrix[0, 0] / (confusion_matrix[0, 0] + confusion_matrix[0, 1])

    auc_test = metrics.roc_auc_score(y_test, y_proba)
    fpr, tpr, threshold = metrics.roc_curve(y_test, y_proba)
    interp_tpr = np.interp(mean_fpr, fpr, tpr)
    interp_tpr[0] = 0

    tprs.append(interp_tpr)
    auc.append(auc_test)
    sensitivities.append(sensitivity)
    specificities.append(specificity)

mean_sens = np.mean(sensitivities)
mean_spec = np.mean(specificities)
print(f"The mean sensitivity of the model is {mean_sens}")
print(f"The mean specificity of the model is {mean_spec}")

tpr_mean = np.mean(tprs, axis=0)
tpr_mean[-1] = 1.0
auc_mean = metrics.auc(mean_fpr, tpr_mean)
std_auc = np.std(auc)

fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(
    mean_fpr,
    tpr_mean,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (auc_mean, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(tpr_mean + std_tpr, 1)
tprs_lower = np.maximum(tpr_mean - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title=f"Mean ROC curve with variability\n(Positive label '{label_encoder.classes_[1]}')",
)
ax.legend(loc="lower right")
plt.show()
# Out:
# The number of samples: 115
# The number of columns: 494
# Number of features that are not normally distributed 408
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 45 fits failed out of a total of 135.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py", line 615, in fit
#     raise NotImplementedError("shrinkage not supported with 'svd' solver.")
# NotImplementedError: shrinkage not supported with 'svd' solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.75087719 0.73976608 0.73918129 0.75087719 0.73976608 0.73918129
#         nan        nan        nan 0.72923977 0.68596491 0.73918129
#  0.72923977 0.68596491 0.73918129        nan        nan        nan
#  0.72923977 0.74035088 0.71871345 0.72923977 0.74035088 0.71871345
#         nan        nan        nan]
#   warnings.warn(
# Best parameters: {'feature_selection__step': 1, 'lda__n_components': None, 'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'scaler': StandardScaler()}
# Validation accuracy: 0.7508771929824561
# Test set accuracy: 0.6956521739130435
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Number of features that are not normally distributed 403
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 45 fits failed out of a total of 135.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py", line 615, in fit
#     raise NotImplementedError("shrinkage not supported with 'svd' solver.")
# NotImplementedError: shrinkage not supported with 'svd' solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.71637427 0.78128655 0.78128655 0.71637427 0.78128655 0.78128655
#         nan        nan        nan 0.74912281 0.77076023 0.75906433
#  0.74912281 0.77076023 0.75906433        nan        nan        nan
#  0.70643275 0.77134503 0.75964912 0.70643275 0.77134503 0.75964912
#         nan        nan        nan]
#   warnings.warn(
# Best parameters: {'feature_selection__step': 1, 'lda__n_components': None, 'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'scaler': RobustScaler()}
# Validation accuracy: 0.7812865497076024
# Test set accuracy: 0.7391304347826086
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Number of features that are not normally distributed 417
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 45 fits failed out of a total of 135.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py", line 615, in fit
#     raise NotImplementedError("shrinkage not supported with 'svd' solver.")
# NotImplementedError: shrinkage not supported with 'svd' solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.69532164 0.77192982 0.73918129 0.69532164 0.77192982 0.73918129
#         nan        nan        nan 0.71695906 0.79356725 0.75906433
#  0.71695906 0.79356725 0.75906433        nan        nan        nan
#  0.70584795 0.81403509 0.73859649 0.70584795 0.81403509 0.73859649
#         nan        nan        nan]
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Best parameters: {'feature_selection__step': 10, 'lda__n_components': None, 'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'scaler': MinMaxScaler()}
# Validation accuracy: 0.8140350877192983
# Test set accuracy: 0.6956521739130435
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Number of features that are not normally distributed 414
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 45 fits failed out of a total of 135.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py", line 615, in fit
#     raise NotImplementedError("shrinkage not supported with 'svd' solver.")
# NotImplementedError: shrinkage not supported with 'svd' solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.7380117  0.77134503 0.73859649 0.7380117  0.77134503 0.73859649
#         nan        nan        nan 0.69649123 0.78245614 0.77134503
#  0.69649123 0.78245614 0.77134503        nan        nan        nan
#  0.79181287 0.79356725 0.74912281 0.79181287 0.79356725 0.74912281
#         nan        nan        nan]
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Best parameters: {'feature_selection__step': 10, 'lda__n_components': None, 'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'scaler': MinMaxScaler()}
# Validation accuracy: 0.7935672514619884
# Test set accuracy: 0.6956521739130435
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Number of features that are not normally distributed 423
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 45 fits failed out of a total of 135.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py", line 615, in fit
#     raise NotImplementedError("shrinkage not supported with 'svd' solver.")
# NotImplementedError: shrinkage not supported with 'svd' solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.7497076  0.76140351 0.78304094 0.7497076  0.76140351 0.78304094
#         nan        nan        nan 0.81637427 0.77251462 0.72923977
#  0.81637427 0.77251462 0.72923977        nan        nan        nan
#  0.72748538 0.76140351 0.73918129 0.72748538 0.76140351 0.73918129
#         nan        nan        nan]
#   warnings.warn(
# Best parameters: {'feature_selection__step': 5, 'lda__n_components': None, 'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'scaler': StandardScaler()}
# Validation accuracy: 0.8163742690058479
# Test set accuracy: 0.7391304347826086
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# The mean sensitivity of the model is 0.6515151515151516
# The mean specificity of the model is 0.7681818181818182

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from worclipo.load_data import load_data
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import preprocessing
from sklearn import decomposition
from sklearn import discriminant_analysis
from sklearn import metrics
from sklearn import model_selection
from sklearn.metrics import RocCurveDisplay, accuracy_score
from scipy import stats
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.kernel_approximation import RBFSampler
from sklearn.metrics.pairwise import rbf_kernel, sigmoid_kernel
from scipy.stats import ttest_ind
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.feature_selection import RFECV

data = load_data()
data.dropna(how='all')

print(f'The number of samples: {len(data.index)}')
print(f'The number of columns: {len(data.columns)}')

#take the labels of the data
label = data.pop('label')
data = data.to_numpy()
label = label.to_numpy()

sss = model_selection.StratifiedKFold(n_splits=5)
mean_fpr = np.linspace(0, 1, 100) #we maken een vector aan waarop we gaan interpoleren
tprs = []
auc = []
specificities = []
sensitivities = []

for train_index, test_index in sss.split(data, label):
    X_train = data[train_index]
    y_train = label[train_index]
    X_test = data[test_index]
    y_test = label[test_index]

    # Voer de t-test uit voor elke feature
    p_values = []

    label1_indices = [index for index, label in enumerate(y_train) if label == 'lipoma']
    label2_indices = [index for index, label in enumerate(y_train) if label == 'liposarcoma']

    for feature in range(X_train.shape[1]):  # num_features is het aantal features in je dataset
        group1 = X_train[label1_indices, feature]
        group2 = X_train[label2_indices, feature]
        _, p_value = ttest_ind(group1, group2)
        p_values.append(p_value)

    # Selecteer features met een p-waarde lager dan de drempel (bijv. 0.05)
    selected_features = [i for i, p_value in enumerate(p_values) if p_value < 0.05]

    # Drop de niet-significante features
    data_selected = X_train[:, selected_features]
    test_selected = X_test[:,selected_features]

    # Maak een DataFrame met de geselecteerde features
    selected_data = pd.DataFrame(data_selected)

    # Voeg de kolomnamen toe aan de DataFrame
    selected_data.columns = [f"feature_{i+1}" for i in selected_features]

    # Definieer de pipeline met schaling, PCA en SVM-classifier
    pipeline = Pipeline([
        ('scaler', preprocessing.StandardScaler()),
        ('feature_selection', RFECV(estimator=SVC(kernel='linear'), scoring='accuracy')),
        ('svm', SVC(probability=True))
        ])

    # Definieer het parametergrid om te doorzoeken
    param_grid = {
        'scaler': [preprocessing.StandardScaler(), MinMaxScaler(), RobustScaler()],
        'feature_selection__step': [1, 5, 10],
        'svm__kernel': ['linear', 'sigmoid', 'rbf', 'poly'], #  Kernel voor SVM
        'svm__C': [1, 10, 100],  # Regularisatieparameter voor SVM
    }

    # Initialiseer de grid search
    grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy')

    # Voer de grid search uit op de data
    grid_search.fit(selected_data, y_train)

    print(f"Best parameters: {grid_search.best_params_}")
    print("Best accuracy:", grid_search.best_score_)
    # Voorspel op de testset met het beste model
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(test_selected)
    y_proba = best_model.predict_proba(test_selected)[:,1]

    #labels 0 of 1 maken
    label_encoder = preprocessing.LabelEncoder()
    y_test = label_encoder.fit_transform(y_test)
    y_pred = label_encoder.fit_transform(y_pred)

    # Evalueren van het beste model op de testset
    accuracy = accuracy_score(y_test, y_pred)
    print("Test set accuracy:", accuracy)

    train_size, train_score, test_score = learning_curve(best_model, selected_data, y_train)
    display = LearningCurveDisplay(train_sizes=train_size, train_scores=train_score, test_scores=test_score)
    display.plot()
    plt.show(block=False)

    confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
    sensitivity = confusion_matrix[1,1]/(confusion_matrix[1,1] + confusion_matrix[1,0])
    specificity = confusion_matrix[0,0]/(confusion_matrix[0,0] + confusion_matrix[0,1])

    auc_test = metrics.roc_auc_score(y_test, y_proba)
    fpr, tpr, threshold = metrics.roc_curve(y_test, y_proba)
    interp_tpr = np.interp(mean_fpr, fpr, tpr)
    interp_tpr[0] = 0

    tprs.append(interp_tpr)
    auc.append(auc_test)
    sensitivities.append(sensitivity)
    specificities.append(specificity)

mean_sens = np.mean(sensitivities)
mean_spec = np.mean(specificities)
print(f"The mean sensitivity of the model is {mean_sens}")
print(f"The mean specificity of the model is {mean_spec}")

tpr_mean = np.mean(tprs, axis=0)
tpr_mean[-1] = 1.0
auc_mean = metrics.auc(mean_fpr, tpr_mean)
std_auc = np.std(auc)

fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(
    mean_fpr,
    tpr_mean,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (auc_mean, std_auc),
    lw=2,
    alpha=0.8,
    )

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(tpr_mean + std_tpr, 1)
tprs_lower = np.maximum(tpr_mean - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
    )

ax.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title=f"Mean ROC curve with variability\n(Positive label '{label_encoder.classes_[1]}')",
    )
ax.legend(loc="lower right")
plt.show()
# Out:
# The number of samples: 115
# The number of columns: 494
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Best parameters: {'feature_selection__step': 10, 'scaler': MinMaxScaler(), 'svm__C': 1, 'svm__kernel': 'linear'}
# Best accuracy: 0.8052631578947368
# Test set accuracy: 0.782608695652174
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Best parameters: {'feature_selection__step': 10, 'scaler': StandardScaler(), 'svm__C': 1, 'svm__kernel': 'sigmoid'}
# Best accuracy: 0.7818713450292398
# Test set accuracy: 0.6521739130434783
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Best parameters: {'feature_selection__step': 5, 'scaler': MinMaxScaler(), 'svm__C': 1, 'svm__kernel': 'rbf'}
# Best accuracy: 0.7719298245614035
# Test set accuracy: 0.6521739130434783
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Best parameters: {'feature_selection__step': 1, 'scaler': MinMaxScaler(), 'svm__C': 1, 'svm__kernel': 'rbf'}
# Best accuracy: 0.8029239766081873
# Test set accuracy: 0.6521739130434783
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Best parameters: {'feature_selection__step': 5, 'scaler': MinMaxScaler(), 'svm__C': 100, 'svm__kernel': 'linear'}
# Best accuracy: 0.8146198830409356
# Test set accuracy: 0.5217391304347826
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# The mean sensitivity of the model is 0.6333333333333333
# The mean specificity of the model is 0.6666666666666666

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from worclipo.load_data import load_data
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import preprocessing
from sklearn import decomposition
from sklearn import discriminant_analysis
from sklearn import metrics
from sklearn import model_selection
from sklearn.metrics import RocCurveDisplay, accuracy_score
from scipy import stats
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.kernel_approximation import RBFSampler
from sklearn.metrics.pairwise import rbf_kernel, sigmoid_kernel
from scipy.stats import ttest_ind
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import RFECV

data = load_data()
data.dropna(how='all')

print(f'The number of samples: {len(data.index)}')
print(f'The number of columns: {len(data.columns)}')

# Take the labels of the data
label = data.pop('label')
data = data.to_numpy()
label = label.to_numpy()

sss = model_selection.StratifiedKFold(n_splits=5)
mean_fpr = np.linspace(0, 1, 100)
tprs = []
auc = []
specificities = []
sensitivities = []

for train_index, test_index in sss.split(data, label):
    X_train = data[train_index]
    y_train = label[train_index]
    X_test = data[test_index]
    y_test = label[test_index]

    # Voer de t-test uit voor elke feature
    p_values = []

    label1_indices = [index for index, label in enumerate(y_train) if label == 'lipoma']
    label2_indices = [index for index, label in enumerate(y_train) if label == 'liposarcoma']

    for feature in range(X_train.shape[1]):
        group1 = X_train[label1_indices, feature]
        group2 = X_train[label2_indices, feature]
        _, p_value = ttest_ind(group1, group2)
        p_values.append(p_value)

    # Selecteer features met een p-waarde lager dan de drempel (bijv. 0.05)
    selected_features = [i for i, p_value in enumerate(p_values) if p_value < 0.05]

    # Drop de niet-significante features
    data_selected = X_train[:, selected_features]
    test_selected = X_test[:, selected_features]

    # Maak een DataFrame met de geselecteerde features
    selected_data = pd.DataFrame(data_selected)

    # Voeg de kolomnamen toe aan de DataFrame
    selected_data.columns = [f"feature_{i+1}" for i in selected_features]

    # Definieer de pipeline met schaling en KNN-classifier
    pipeline = Pipeline([
        ('scaler', preprocessing.StandardScaler()),
        ('feature_selection', RFECV(estimator=SVC(kernel='linear'), scoring='accuracy')),  # Voeg RFECV toe als feature selector
        ('knn', KNeighborsClassifier())
    ])

    # Definieer het parametergrid om te doorzoeken
    param_grid = {
        'scaler': [preprocessing.StandardScaler(), MinMaxScaler(), RobustScaler()],
        'feature_selection__step': [1, 5, 10],  # Aantal features om per iteratie te verwijderen
        'knn__n_neighbors': [1, 5, 9, 13],  # Aantal buren
    }

    # Initialiseer de grid search
    grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy')

    # Voer de grid search uit op de data
    grid_search.fit(selected_data, y_train)

    # Bekijk de beste parameters en score
    print("Best parameters:", grid_search.best_params_)
    print("Beste score accuracy:", grid_search.best_score_)

    # Voorspel op de testset met het beste model
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(test_selected)
    y_proba = best_model.predict_proba(test_selected)[:, 1]

    # Labels encoderen
    label_encoder = preprocessing.LabelEncoder()
    y_test = label_encoder.fit_transform(y_test)
    y_pred = label_encoder.fit_transform(y_pred)

    # Evalueren van het beste model op de testset
    accuracy = accuracy_score(y_test, y_pred)
    print("Test set accuracy:", accuracy)

    train_size, train_score, test_score = learning_curve(best_model, selected_data, y_train)
    display = LearningCurveDisplay(train_sizes=train_size, train_scores=train_score, test_scores=test_score, score_name="Accuracy")
    display.plot()
    plt.show(block=False)

    confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
    sensitivity = confusion_matrix[1,1]/(confusion_matrix[1,1] + confusion_matrix[1,0])
    specificity = confusion_matrix[0,0]/(confusion_matrix[0,0] + confusion_matrix[0,1])

    auc_test = metrics.roc_auc_score(y_test, y_proba)
    fpr, tpr, threshold = metrics.roc_curve(y_test, y_proba)
    interp_tpr = np.interp(mean_fpr, fpr, tpr)
    interp_tpr[0] = 0

    tprs.append(interp_tpr)
    auc.append(auc_test)
    sensitivities.append(sensitivity)
    specificities.append(specificity)

mean_sens = np.mean(sensitivities)
mean_spec = np.mean(specificities)
print(f"The mean sensitivity of the model is {mean_sens}")
print(f"The mean specificity of the model is {mean_spec}")

tpr_mean = np.mean(tprs, axis=0)
tpr_mean[-1] = 1.0
auc_mean = metrics.auc(mean_fpr, tpr_mean)
std_auc = np.std(auc)


fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(
    mean_fpr,
    tpr_mean,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (auc_mean, std_auc),
    lw=2,
    alpha=0.8,
    )

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(tpr_mean + std_tpr, 1)
tprs_lower = np.maximum(tpr_mean - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
    )

ax.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title=f"Mean ROC curve with variability\n(Positive label '{label_encoder.classes_[1]}')",
    )
ax.legend(loc="lower right")
plt.show()
# Out:
# The number of samples: 115
# The number of columns: 494
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Best parameters: {'feature_selection__step': 10, 'knn__n_neighbors': 13, 'scaler': MinMaxScaler()}
# Beste score accuracy: 0.7719298245614035
# Test set accuracy: 0.6956521739130435
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Best parameters: {'feature_selection__step': 5, 'knn__n_neighbors': 9, 'scaler': MinMaxScaler()}
# Beste score accuracy: 0.8029239766081873
# Test set accuracy: 0.782608695652174
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Best parameters: {'feature_selection__step': 10, 'knn__n_neighbors': 13, 'scaler': RobustScaler()}
# Beste score accuracy: 0.7824561403508772
# Test set accuracy: 0.5652173913043478
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RobustScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RobustScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 722, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 668, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py", line 234, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py", line 810, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 7, n_neighbors = 13
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 722, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 668, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py", line 234, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py", line 810, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 7, n_neighbors = 13
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Best parameters: {'feature_selection__step': 10, 'knn__n_neighbors': 5, 'scaler': MinMaxScaler()}
# Beste score accuracy: 0.7385964912280701
# Test set accuracy: 0.6956521739130435
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Best parameters: {'feature_selection__step': 1, 'knn__n_neighbors': 9, 'scaler': StandardScaler()}
# Beste score accuracy: 0.8040935672514621
# Test set accuracy: 0.5652173913043478
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 722, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 668, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py", line 234, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py", line 810, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 7, n_neighbors = 9
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 722, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 668, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py", line 234, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py", line 810, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 7, n_neighbors = 9
#
#   warnings.warn(
# The mean sensitivity of the model is 0.6166666666666667
# The mean specificity of the model is 0.7

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from worclipo.load_data import load_data
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import preprocessing
from sklearn import decomposition
from sklearn import discriminant_analysis
from sklearn import metrics
from sklearn import model_selection
from sklearn.metrics import RocCurveDisplay, accuracy_score
from scipy import stats
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.kernel_approximation import RBFSampler
from sklearn.metrics.pairwise import rbf_kernel, sigmoid_kernel
from scipy.stats import ttest_ind
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import ttest_ind
from sklearn.feature_selection import RFECV

data = load_data()
data.dropna(how='all')

print(f'The number of samples: {len(data.index)}')
print(f'The number of columns: {len(data.columns)}')

# Take the labels of the data
label = data.pop('label')
data = data.to_numpy()
label = label.to_numpy()

sss = model_selection.StratifiedKFold(n_splits=5)
mean_fpr = np.linspace(0, 1, 100)  # we maken een vector aan waarop we gaan interpoleren
tprs = []
auc = []
specificities = []
sensitivities = []

for train_index, test_index in sss.split(data, label):
    X_train = data[train_index]
    y_train = label[train_index]
    X_test = data[test_index]
    y_test = label[test_index]

    # Voer de t-test uit voor elke feature
    p_values = []

    label1_indices = [index for index, label in enumerate(y_train) if label == 'lipoma']
    label2_indices = [index for index, label in enumerate(y_train) if label == 'liposarcoma']

    for feature in range(X_train.shape[1]):  # num_features is het aantal features in je dataset
        group1 = X_train[label1_indices, feature]
        group2 = X_train[label2_indices, feature]
        _, p_value = ttest_ind(group1, group2)
        p_values.append(p_value)

    # Selecteer features met een p-waarde lager dan de drempel (bijv. 0.05)
    selected_features = [i for i, p_value in enumerate(p_values) if p_value < 0.05]

    # Drop de niet-significante features
    data_selected = X_train[:, selected_features]
    test_selected = X_test[:, selected_features]

    # Maak een DataFrame met de geselecteerde features
    selected_data = pd.DataFrame(data_selected)

    # Voeg de kolomnamen toe aan de DataFrame
    selected_data.columns = [f"feature_{i+1}" for i in selected_features]

    # Definieer de pipeline met schaling en Random Forest classifier
    pipeline = Pipeline([
        ('scaler', preprocessing.StandardScaler()),
        ('feature_selection', RFECV(estimator=SVC(kernel='linear'), scoring='accuracy')),  # Voeg RFECV toe als feature selector
        ('rf', RandomForestClassifier())
    ])

    # Definieer het parametergrid om te doorzoeken
    param_grid = {
        'scaler':  [MinMaxScaler(), RobustScaler(), StandardScaler()],
        'feature_selection__step': [1, 5, 10],  # Aantal features om per iteratie te verwijderen
        'rf__n_estimators': [2, 10, 40, 80],  # Aantal bomen in het forest
        'rf__max_depth': [2, 4, 6, 8, 10],  # Maximale diepte van de bomen
    }

    # Initialiseer de grid search
    grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy')

    # Voer de grid search uit op de data
    grid_search.fit(selected_data, y_train)

    # Bekijk de beste parameters en score
    print("Best parameters:", grid_search.best_params_)
    print("Best accuracy:", grid_search.best_score_)

    # Voorspel op de testset met het beste model
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(test_selected)
    y_proba = best_model.predict_proba(test_selected)[:, 1]

    #labels 0 of 1 maken
    label_encoder = preprocessing.LabelEncoder()
    y_test = label_encoder.fit_transform(y_test)
    y_pred = label_encoder.fit_transform(y_pred)

    # Evalueren van het beste model op de testset
    accuracy = accuracy_score(y_test, y_pred)
    print("Test set accuracy:", accuracy)

    train_size, train_score, test_score = learning_curve(best_model, selected_data, y_train)
    display = LearningCurveDisplay(train_sizes=train_size, train_scores=train_score, test_scores=test_score, score_name="Accuracy")
    display.plot()
    plt.show(block=False)

    confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
    sensitivity = confusion_matrix[1, 1] / (confusion_matrix[1, 1] + confusion_matrix[1, 0])
    specificity = confusion_matrix[0, 0] / (confusion_matrix[0, 0] + confusion_matrix[0, 1])

    auc_test = metrics.roc_auc_score(y_test, y_proba)
    fpr, tpr, threshold = metrics.roc_curve(y_test, y_proba)
    interp_tpr = np.interp(mean_fpr, fpr, tpr)
    interp_tpr[0] = 0

    tprs.append(interp_tpr)
    auc.append(auc_test)
    sensitivities.append(sensitivity)
    specificities.append(specificity)

mean_sens = np.mean(sensitivities)
mean_spec = np.mean(specificities)
print(f"The mean sensitivity of the model is {mean_sens}")
print(f"The mean specificity of the model is {mean_spec}")

tpr_mean = np.mean(tprs, axis=0)
tpr_mean[-1] = 1.0
auc_mean = metrics.auc(mean_fpr, tpr_mean)
std_auc = np.std(auc)

fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(
    mean_fpr,
    tpr_mean,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (auc_mean, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(tpr_mean + std_tpr, 1)
tprs_lower = np.maximum(tpr_mean - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title=f"Mean ROC curve with variability\n(Positive label '{label_encoder.classes_[1]}')",
)
ax.legend(loc="lower right")
plt.show()
# Out:
# The number of samples: 115
# The number of columns: 494
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Best parameters: {'feature_selection__step': 10, 'rf__max_depth': 6, 'rf__n_estimators': 80, 'scaler': MinMaxScaler()}
# Best accuracy: 0.7719298245614035
# Test set accuracy: 0.8260869565217391
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Best parameters: {'feature_selection__step': 5, 'rf__max_depth': 4, 'rf__n_estimators': 10, 'scaler': RobustScaler()}
# Best accuracy: 0.7923976608187134
# Test set accuracy: 0.7391304347826086
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RobustScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RobustScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Best parameters: {'feature_selection__step': 5, 'rf__max_depth': 2, 'rf__n_estimators': 40, 'scaler': StandardScaler()}
# Best accuracy: 0.8035087719298246
# Test set accuracy: 0.6956521739130435
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Best parameters: {'feature_selection__step': 10, 'rf__max_depth': 2, 'rf__n_estimators': 40, 'scaler': StandardScaler()}
# Best accuracy: 0.7608187134502924
# Test set accuracy: 0.782608695652174
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# Best parameters: {'feature_selection__step': 1, 'rf__max_depth': 2, 'rf__n_estimators': 2, 'scaler': MinMaxScaler()}
# Best accuracy: 0.8157894736842106
# Test set accuracy: 0.6521739130434783
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# The mean sensitivity of the model is 0.7030303030303029
# The mean specificity of the model is 0.7696969696969697
